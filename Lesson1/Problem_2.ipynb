# %% [markdown]
# ![Problem_2.jpg](attachment:Problem_2.jpg)#

# %%
import numpy as np
M1 = np.array([[3., -2., 5.], [7., 4., -8.], [5.,-3.,-4.]]) # Матрица (левая часть системы)
v1 = np.array([7., 3., -12.]) # Вектор (правая часть системы)

print(np.linalg.solve(M1, v1))
# Out:
# [1. 3. 2.]
