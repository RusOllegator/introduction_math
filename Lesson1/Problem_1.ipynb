# %% [markdown]
# # ![Problem_1.jpg](attachment:Problem_1.jpg)

# %%
import numpy as np
a = np.array([[5,10],[7,12],[11.3,5],[25,30]])
b = np.array([[5,10],[7,12],[11.3,5],[25,30]])
c = 7*a + 2*b
print(c)
# Out:
# [[ 45.   90. ]
#  [ 63.  108. ]
#  [101.7  45. ]
#  [225.  270. ]]
